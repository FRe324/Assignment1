# %% [markdown]
# # Assignment 1

# %% [markdown]
# 1. What are the differences between operators and values in the following?
# *
# 'hello'
# -87.8
# -
# /
# +
# 6

# %% [markdown]
# answer
# Operators:: +, -, *, /
# Values:: 'hello', -88.5, 5

# %% [markdown]
# 2. What is the difference between string and variable?
# spam
# 'spam'
#
# answer :: string always get assigned to some variable,and always present in quotes.

# %% [markdown]
# 3.Describe three different data forms.

# %% [markdown]
# answer:: str , int , float

# %% [markdown]
# 4. What makes up an expression? What are the functions of all expressions?

# %% [markdown]
# answer:: expression is made up of operators and variables . expressions are to assign the values to the

# %% [markdown]
# 5. In this chapter, assignment statements such as spam = 10 were added. Whats the
# difference between a declaration and an expression?

# %% [markdown]
# declaration is uses to assign the type of variable. expression is use to evaluate.

# %% [markdown]
# 6. After running the following code, what does the variable bacon contain?
# bacon=22
# bacon+1

# %% [raw]
# answer :: the variable bacon will contain 22 cause after second statement the value is not assigned to the bacon

# %% [markdown]
# 7. What should the values of the following two terms be?
# 'spam'+'spamspam'
# 'spam'*3

# %% [markdown]
# answer:: both the terms will show output as 'spamspamspam'

# %% [markdown]
# 8. Why is it that eggs is a true variable name but 100 is not?

# %% [markdown]
# answer:: the name of variable cannot be the numerical value

# %% [markdown]
# 9. Which of the following three functions may be used to convert a value to an integer, a
# floating-point number, or a string?

# %% [markdown]
# answer:: the three functions are as follows int(), float(),str().

# %% [markdown]
# 10. What is the error caused by this expression? What would you do about it?
# "ihave eaten"+ 99 "buritos."

# %% [markdown]
# answer:: the error cause string cannot concatenated with int values
# "i have eaten"+str(99)+"buritos."
